# %%
import pandas as pd
from sklearn import datasets
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = datasets.load_breast_cancer()

# %%
x_norm =pd.DataFrame(df.data, columns=df.feature_names)
y = df.target

# %% [markdown]
# # PCA (Principle component analysis)

# %%
#Scaling feaures
from sklearn.preprocessing import StandardScaler
Scaler = StandardScaler()
Scaler.fit(x_norm, y)
ConX = Scaler.transform(x_norm)
x_trans =pd.DataFrame(ConX, columns=df.feature_names)


#PCA
from sklearn.decomposition import PCA
pca = PCA(n_components = 2)
pca.fit(x_trans, y)
Dx = pca.fit_transform(x)
Dx.shape


x_dim =pd.DataFrame(Dx, columns=['a', 'b'])

# %% [markdown]
# # curse of dimensionaility

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_dim, y, test_size = 0.5, random_state = 0)
Model = LinearRegression()
Model.fit(x_train, y_train)
y_pred = Model.predict(x_test)

from sklearn.metrics import r2_score
score = r2_score(y_test, y_pred)

# %%
# plt.figure(figsize = (10, 6))
# plt.scatter(x_dim['a'], x_dim['b'],c=y, s=20)

# plt.show()
plt.plot(x=range(1, ))
